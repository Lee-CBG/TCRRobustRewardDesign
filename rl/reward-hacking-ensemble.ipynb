# %%
import os
import wandb
import torch
import json
import csv
import subprocess
import pandas as pd
import numpy as np
from tqdm import tqdm
from datasets import Dataset
from transformers import GPT2Tokenizer
from trl import PPOTrainer, PPOConfig, AutoModelForCausalLMWithValueHead, create_reference_model

os.environ["CUDA_VISIBLE_DEVICES"] = "3"


# ---- I/O helpers ----
def load_data(train_path):
    with open(train_path, "r") as f:
        return [line.strip() for line in f]

def split_line(line):
    epi, tcr = line.split("$")
    return epi + "$", tcr

def save_to_csv_1(epis, tcrs, csv_file_path="tmp_epis_tcrs.csv"):
    with open(csv_file_path, mode="w", newline="") as file:
        writer = csv.DictWriter(file, fieldnames=["Epitopes", "TCRs"])
        writer.writeheader()
        for epi, tcr in zip(epis, tcrs):
            writer.writerow({"Epitopes": epi, "TCRs": tcr})

def append_tmp_to_master(tmp_filename="tmp_epis_tcrs.csv", master_filename="all_results.csv"):
    master_exists = os.path.isfile(master_filename)
    tmp_df = pd.read_csv(tmp_filename)
    tmp_df.to_csv(master_filename, mode="a", header=not master_exists, index=False)

def collator(data):
    return {key: [d[key] for d in data] for key in data[0]}

def shannon_entropy(seq):
    import math
    from collections import Counter
    counts = Counter(seq)
    probs = [v / len(seq) for v in counts.values()]
    return -sum(p * math.log(p + 1e-9) for p in probs)

def longest_homopolymer(seq):
    if not seq:
        return 0
    longest, cur = 1, 1
    for a, b in zip(seq, seq[1:]):
        cur = cur + 1 if a == b else 1
        longest = max(longest, cur)
    return longest


# ---- Reward backend command builder ----
def build_reward_cmd(backend):
    if backend == "tcrbert":
        return (
            "conda run -n trl "
            "python rewards/tcrbert_bap_infer.py "
            "--input-path tmp_epis_tcrs.csv "
            "--output-path tmp_epis_tcrs.csv "
            "--model-path rewards/tcrbert_bap_head_robust.pth"
        )
    elif backend == "catelmo":
        return (
            "conda run -n trl "
            "python rewards/catelmo_bap_infer.py "
            "--input-path tmp_epis_tcrs.csv "
            "--output-path tmp_epis_tcrs.csv "
            "--model-path rewards/catelmo_bap_head_robust.pth"
        )
    else:  # cnn or lstm
        return (
            "/home/hmei7/workspace/.conda/envs/tf26/bin/python "
            "rewards/bap_ensemble/ensemble_bap.py "
            "--mode inference "
            "--testfile tmp_epis_tcrs.csv "
            f"--bap {backend}"
        )

        # return (
        #     'bash -c "conda activate /home/hmei7/workspace/.conda/envs/tf26 && ' #  && '
        #     'python rewards/bap_ensemble/ensemble_bap.py '
        #     '--mode inference '
        #     '--testfile tmp_epis_tcrs.csv '
        #     f'--bap {backend}"'
        # )

def run_reward_backend(backend):
    cmd = build_reward_cmd(backend)
    subprocess.run(cmd, shell=True, check=True)
    # append_tmp_to_master()

# %%
# ---- CONFIG / CONSTS ----
# REWARD_BACKEND = "cnn"  # options: "tcrbert", "catelmo", "cnn", "lstm"
BASE_CKPT_DIR = "ckpts/catelmo_ensemble"
SAVE_EVERY = 5
os.makedirs(BASE_CKPT_DIR, exist_ok=True)
INCLUDE_HEURISTIC = False
# SPECIFITY = None # Placeholder for future use infonce or maxmargin


HEURISTIC_CFG = {
    "L_MIN": 9,
    "L_MAX": 21,
    "ENTROPY_FLOOR": 1.76,
    "RUN_MAX_ALLOWED": 3, # Max allowed homopolymer run (e.g., 'AAAA')
    "BAD_SEQ_PENALTY": -10.0,
    "MAX_REWARD": 10.0,
}

# ========================
# Configuration
# ========================
config = PPOConfig(
    model_name="/home/hmei7/workspace/tcr/models_gen/checkpoint-1600",
    learning_rate=1.41e-5, 
    batch_size=128,
    mini_batch_size=32, 
    ppo_epochs=2, # 2
    gradient_accumulation_steps=2,
    max_grad_norm=0.4,
    init_kl_coef=0.1, #[0.00, 0.02, 0.05, 1.0]
    adap_kl_ctrl=False,
    # target_kl=0.03,
    log_with="wandb",
    tracker_project_name="tcr-rlhf-goodhart",
)

# ========================
# Load Model and Tokenizer
# ========================
model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
model_ref = create_reference_model(model)
tokenizer = GPT2Tokenizer.from_pretrained("/home/hmei7/workspace/tcr/models_gen/aa_tokenizer_trained")
tokenizer.pad_token = tokenizer.eos_token


dataset_lines = load_data('data/epi_training.txt')
epis, tcrs = [], []
for line in dataset_lines:
    epi, tcr = split_line(line)
    epis.append(epi)
    tcrs.append(tcr)
epis = list(set(epis))  # deduplicate epitopes
print(f"Loaded {len(epis)} epitopes:")
my_dataset = {"epis": epis}
dataset = Dataset.from_dict(my_dataset)
dataset.set_format("pytorch")


# Tokenization & Query Construction
dataset = dataset.map(
    lambda x: {"input_ids": tokenizer.encode(x["epis"], return_tensors="pt")[0, :64].to(model.pretrained_model.device)},
    batched=False,
)
dataset = dataset.map(
    lambda x: {"query": tokenizer.decode(x["input_ids"])},
    batched=False
)

# ========================
# Initialize PPO Trainer
# ========================
ppo_trainer = PPOTrainer(config, model, model_ref, tokenizer, dataset=dataset, data_collator=collator)


# ========================
# Generation Configuration
# ========================
generation_kwargs = {
    "min_length": 2,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
    "eos_token_id": tokenizer.eos_token_id,
    # "max_length": 72,
    "max_new_tokens": 42,  
}

# ========================
# Training Loop
# ========================
global_step = 0
for epoch in tqdm(range(10)):
    for batch in ppo_trainer.dataloader:
        
        # ---- batch generations ----
        query_tensors = batch["input_ids"]                 # List[Tensor], variable lengths
        queries_text   = batch.get("query", None)          # optional, if you want raw text

        with torch.no_grad():                              
            gen_full = ppo_trainer.generate(list(query_tensors), **generation_kwargs)
        prompt_lens = [int(q.shape[-1]) for q in query_tensors]
        response_tensors = [g[p_len:] for g, p_len in zip(gen_full, prompt_lens)]
        batch["response"] = tokenizer.batch_decode(response_tensors, skip_special_tokens=False)
        

        # ---- extract epi/tcr ----
        epis = [tokenizer.decode(r.squeeze())[:-2] for r in query_tensors]
        tcrs = [resp.split('<EOS>')[0] for resp in batch["response"]]
        special_tokens = ["<PAD>", "<tcr>", "<eotcr>", "[CLS]", "[BOS]", "[MASK]", "[SEP]", "<epi>", "<eoepi>", "$", "<unk>"]
        tcrs = ['WRONGFORMAT' if (not s or any(tok in s for tok in special_tokens)) else s for s in tcrs]
        save_to_csv_1(epis, tcrs, 'tmp_epis_tcrs.csv')


        
        # ---- Ensemble 3 reward backends sequentially ----
        for REWARD_BACKEND in ("catelmo", "cnn", "lstm"):
            run_reward_backend(REWARD_BACKEND)
        append_tmp_to_master()


        # ---- I/O reward values ----
        df_rewards = pd.read_csv("tmp_epis_tcrs.csv")
        bap_cols = [c for c in ["logits", "bap_cnn", "bap_lstm"] if c in df_rewards.columns]
        if not bap_cols:
            raise RuntimeError("No BAP columns found in tmp_epis_tcrs.csv")

        # simple mean ensemble; NaNs ignored per-row
        reward_values = df_rewards[bap_cols].astype(float).mean(axis=1, skipna=True).tolist()

        if INCLUDE_HEURISTIC:
            # reward_values, bad_count = apply_heuristic_penalties(reward_values, tcrs, HEURISTIC_CFG)
            # print(f"[Heuristic] {bad_count}/{len(tcrs)} sequences penalized this batch.")
            bad_count = 0
            for i, tcr in enumerate(tcrs):
                if tcr == "WRONGFORMAT" or len(tcr) < 5:
                    reward_values[i] = HEURISTIC_CFG["BAD_SEQ_PENALTY"]
                    bad_count += 1
                    continue

                L = len(tcr)
                H = shannon_entropy(tcr)
                R = longest_homopolymer(tcr)

                # range checks
                if not (HEURISTIC_CFG["L_MIN"] <= L <= HEURISTIC_CFG["L_MAX"]) \
                   or H < HEURISTIC_CFG["ENTROPY_FLOOR"] \
                   or R > HEURISTIC_CFG["RUN_MAX_ALLOWED"]:
                    reward_values[i] = HEURISTIC_CFG["BAD_SEQ_PENALTY"]
                    bad_count += 1

            # Clip large rewards
            reward_values = [min(v, HEURISTIC_CFG["MAX_REWARD"]) for v in reward_values]
            print(f"[Heuristic] {bad_count}/{len(tcrs)} sequences penalized this batch.")


            
        rewards_bap = [torch.tensor(float(v), dtype=torch.float32) for v in reward_values]

        # PPO Step
        stats = ppo_trainer.step(query_tensors, response_tensors, rewards_bap)
        ppo_trainer.log_stats(stats, batch, rewards_bap)
        
        # ---- save checkpoints ----
        global_step += 1
        if global_step % SAVE_EVERY == 0 and ppo_trainer.accelerator.is_main_process:
            ckpt_dir = os.path.join(BASE_CKPT_DIR, f"step_{global_step:04d}")
            os.makedirs(ckpt_dir, exist_ok=True)
            ppo_trainer.save_pretrained(ckpt_dir)
            tokenizer.save_pretrained(ckpt_dir)
            print(f"[Checkpoint] Saved to {ckpt_dir}")

    print(f'\nEpoch {epoch}:')
    print(tcrs[:20])
# Out:
# /home/hmei7/workspace/.conda/envs/bap_attack/lib/python3.10/site-packages/trl/trainer/ppo_config.py:207: FutureWarning: `PPOConfig` is deprecated and will be removed in the future. Please use `PPOv2Config` with `PPOv2Trainer` instead.
#   warnings.warn(
# /home/hmei7/workspace/.conda/envs/bap_attack/lib/python3.10/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /home/hmei7/workspace/.conda/envs/bap_attack/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Loaded 786 epitopes:
# Map:   0%|          | 0/786 [00:00<?, ? examples/s]
# Map:   0%|          | 0/786 [00:00<?, ? examples/s]
# /home/hmei7/workspace/.conda/envs/bap_attack/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:193: FutureWarning: `PPOTrainer` is deprecated and will be removed in trl v0.12. Please use `PPOv2Trainer` instead.
#   warnings.warn(
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: pengfeiz. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/mnt/disk11/user/pzhang84/recomb25/wandb/run-20251119_232224-l1hry3sm</code>
# Syncing run <strong><a href='https://wandb.ai/pengfeiz/tcr-rlhf-goodhart/runs/l1hry3sm' target="_blank">super-donkey-170</a></strong> to <a href='https://wandb.ai/pengfeiz/tcr-rlhf-goodhart' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/pengfeiz/tcr-rlhf-goodhart' target="_blank">https://wandb.ai/pengfeiz/tcr-rlhf-goodhart</a>
#  View run at <a href='https://wandb.ai/pengfeiz/tcr-rlhf-goodhart/runs/l1hry3sm' target="_blank">https://wandb.ai/pengfeiz/tcr-rlhf-goodhart/runs/l1hry3sm</a>
#   0%|          | 0/10 [00:00<?, ?it/s]
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/128 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/128 [00:00<00:00, 235.46 examples/s]
# Map (num_proc=4): 100%|██████████| 128/128 [00:00<00:00, 393.21 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.28it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.09it/s]
#
# 2025-11-19 23:22:35.629903: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:22:35.642320: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:22:35.657025: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:22:35.661300: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:22:35.672528: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:22:37.200419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763594558.125755 1215259 service.cc:146] XLA service 0x7c2070017700 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763594558.125831 1215259 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:22:38.162471: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:22:38.235451: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763594558.802652 1215259 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:22:39.894254: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:22:39.906515: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:22:39.921330: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:22:39.925598: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:22:39.936762: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:22:41.470823: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# 2025-11-19 23:22:43.223155: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/128 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/128 [00:00<00:00, 198.36 examples/s]
# Map (num_proc=4): 100%|██████████| 128/128 [00:00<00:00, 353.53 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.28it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.09it/s]
#
# 2025-11-19 23:22:54.458729: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:22:54.470903: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:22:54.485756: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:22:54.490007: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:22:54.501219: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:22:56.026387: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763594576.951591 1216888 service.cc:146] XLA service 0x7ff458015060 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763594576.951626 1216888 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:22:56.987952: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:22:57.059327: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763594577.626568 1216888 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:22:58.711996: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:22:58.724383: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:22:58.739022: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:22:58.743287: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:22:58.754500: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:23:00.277605: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# 2025-11-19 23:23:02.103471: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/128 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/128 [00:00<00:00, 193.97 examples/s]
# Map (num_proc=4): 100%|██████████| 128/128 [00:00<00:00, 429.11 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.28it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.12it/s]
#
# 2025-11-19 23:23:12.904566: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:23:12.916947: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:23:12.931597: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:23:12.935864: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:23:12.947052: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:23:14.479029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763594595.405833 1218500 service.cc:146] XLA service 0x7a74e00044f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763594595.405868 1218500 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:23:15.421489: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:23:15.481194: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763594596.042234 1218500 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:23:17.162817: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:23:17.175324: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:23:17.190042: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:23:17.194331: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:23:17.205588: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:23:18.732828: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# 2025-11-19 23:23:20.510050: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/127 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/127 [00:00<00:00, 245.09 examples/s]
# Map (num_proc=4): 100%|██████████| 127/127 [00:00<00:00, 408.70 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
#
# 2025-11-19 23:23:31.353882: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:23:31.366343: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:23:31.381047: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:23:31.385326: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:23:31.396595: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:23:32.930461: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763594613.866887 1220123 service.cc:146] XLA service 0x7dd1a4003660 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763594613.866917 1220123 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:23:33.903304: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:23:33.975665: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763594614.547840 1220123 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:23:35.636762: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:23:35.648934: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:23:35.663744: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:23:35.668019: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:23:35.679176: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:23:37.200960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# 2025-11-19 23:23:39.076473: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/127 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/127 [00:00<00:00, 227.05 examples/s]
# Map (num_proc=4): 100%|██████████| 127/127 [00:00<00:00, 420.52 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.22it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.02it/s]
#
# 2025-11-19 23:23:49.996639: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:23:50.009077: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:23:50.023775: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:23:50.028044: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:23:50.039284: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:23:51.600326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763594632.535325 1221908 service.cc:146] XLA service 0x7612e0002630 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763594632.535366 1221908 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:23:52.572368: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:23:52.644438: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763594633.193415 1221908 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:23:54.291166: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:23:54.303477: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:23:54.318412: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:23:54.322696: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:23:54.333929: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:23:55.878193: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# 2025-11-19 23:23:57.686436: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# /home/hmei7/workspace/.conda/envs/bap_attack/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1431: UserWarning: Cannot retrieve user information assuming you are running in offline mode.
#   warnings.warn("Cannot retrieve user information assuming you are running in offline mode.")
# [Checkpoint] Saved to ckpts/catelmo_ensemble/step_0005
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/127 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/127 [00:00<00:00, 241.18 examples/s]
# Map (num_proc=4): 100%|██████████| 127/127 [00:00<00:00, 473.44 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.31it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.12it/s]
#
# 2025-11-19 23:24:08.608066: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:24:08.620439: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:24:08.635104: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:24:08.639351: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:24:08.650539: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:24:10.185691: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763594651.111822 1223605 service.cc:146] XLA service 0x79a3cc006ea0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763594651.111855 1223605 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:24:11.148143: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:24:11.219563: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763594651.755953 1223605 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:24:12.840789: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:24:12.853343: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:24:12.868182: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:24:12.872561: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:24:12.883858: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:24:14.417136: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# 2025-11-19 23:24:16.324683: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
#  10%|█         | 1/10 [01:52<16:48, 112.09s/it]
# Epoch 0:
# ['CASSLAGGAYEQYF', 'CASSPQGVDTQYF', 'CASSLGGDTEAFF', 'CASTDEQYF', 'CASSSLGGYEQYF', 'CASRAGAEQYF', 'CASSLGGSYEQYF', 'CASSLQGTYEQYF', 'CASSLAGAGGEQYF', 'CASSLGLYEQFF', 'ASYEQY', 'CASSFGGLGEQYF', 'CASSLGTEAFF', 'ASSDVGRSYEQY', 'CASSLAGGEAFF', 'ASSGLAGAYEQY', 'ASSQGGYGYT', 'CASSLGYEQYF', 'CASSQGNEQYF', 'CASSLEGDEQYF']
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/128 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/128 [00:00<00:00, 238.28 examples/s]
# Map (num_proc=4): 100%|██████████| 128/128 [00:00<00:00, 416.54 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.24it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.04it/s]
#
# 2025-11-19 23:24:26.873235: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:24:26.885694: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:24:26.900411: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:24:26.904709: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:24:26.916019: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:24:28.466902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763594669.400119 1225316 service.cc:146] XLA service 0x729ef0003f00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763594669.400183 1225316 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:24:29.436723: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:24:29.509244: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763594670.063280 1225316 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:24:31.165563: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:24:31.177778: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:24:31.192670: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:24:31.196986: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:24:31.208192: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:24:32.742316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# 2025-11-19 23:24:34.553694: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/128 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/128 [00:00<00:00, 230.55 examples/s]
# Map (num_proc=4): 100%|██████████| 128/128 [00:00<00:00, 433.91 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.27it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.09it/s]
#
# 2025-11-19 23:24:45.103192: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:24:45.115586: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:24:45.130528: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:24:45.134818: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:24:45.146120: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:24:46.687101: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763594687.628362 1227110 service.cc:146] XLA service 0x74b554003a60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763594687.628401 1227110 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:24:47.640276: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:24:47.688131: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763594688.203904 1227110 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:24:49.334499: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:24:49.346931: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:24:49.361659: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:24:49.365941: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:24:49.377206: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:24:50.916907: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# 2025-11-19 23:24:52.723461: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/127 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/127 [00:00<00:00, 244.89 examples/s]
# Map (num_proc=4): 100%|██████████| 127/127 [00:00<00:00, 419.33 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.39it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.20it/s]
#
# 2025-11-19 23:25:03.209038: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:25:03.221756: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:25:03.236839: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:25:03.241163: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:25:03.252533: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:25:04.793122: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763594705.731354 1229116 service.cc:146] XLA service 0x7581e4002110 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763594705.731401 1229116 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:25:05.767661: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:25:05.839926: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763594706.388102 1229116 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:25:07.466211: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:25:07.478514: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:25:07.493430: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/127 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/127 [00:00<00:00, 251.90 examples/s]
# Map (num_proc=4): 100%|██████████| 127/127 [00:00<00:00, 453.92 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.37it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.16it/s]
#
# 2025-11-19 23:39:40.045795: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:39:40.058084: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:39:40.072854: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:39:40.077414: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:39:40.088390: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:39:41.620024: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763595582.512132 1311577 service.cc:146] XLA service 0x78b954005150 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763595582.512194 1311577 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:39:42.549385: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:39:42.623519: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763595583.206888 1311577 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:39:44.290911: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:39:44.303094: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:39:44.318023: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:39:44.322289: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:39:44.333538: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:39:45.860769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# 2025-11-19 23:39:47.568801: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/128 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/128 [00:00<00:00, 195.20 examples/s]
# Map (num_proc=4): 100%|██████████| 128/128 [00:00<00:00, 350.63 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.26it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.10it/s]
#
# 2025-11-19 23:39:57.700783: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:39:57.712989: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:39:57.727376: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:39:57.731645: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:39:57.742552: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:39:59.269144: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763595600.172604 1313194 service.cc:146] XLA service 0x707cac016830 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763595600.172643 1313194 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:40:00.208938: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:40:00.280629: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763595600.857666 1313194 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:40:01.935159: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:40:01.947592: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:40:01.962719: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:40:01.966993: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:40:01.978227: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:40:03.512577: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# 2025-11-19 23:40:05.417245: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 43
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /mnt/disk11/user/pzhang84/anaconda3/envs/trl/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Map (num_proc=4):   0%|          | 0/128 [00:00<?, ? examples/s]
# Map (num_proc=4):  25%|██▌       | 32/128 [00:00<00:00, 227.80 examples/s]
# Map (num_proc=4): 100%|██████████| 128/128 [00:00<00:00, 458.33 examples/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.31it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.13it/s]
#
# 2025-11-19 23:40:15.429312: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:40:15.441728: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:40:15.456766: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:40:15.461097: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:40:15.472393: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:40:17.011739: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763595617.914300 1314833 service.cc:146] XLA service 0x7a3068004950 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763595617.914364 1314833 service.cc:154]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-11-19 23:40:17.951645: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-19 23:40:18.023706: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# I0000 00:00:1763595618.597595 1314833 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-19 23:40:19.743066: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 23:40:19.755359: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-19 23:40:19.770370: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-19 23:40:19.774659: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-19 23:40:19.786035: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 23:40:21.316493: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43519 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:c3:00.0, compute capability: 8.9
# 2025-11-19 23:40:23.039081: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# /home/hmei7/workspace/.conda/envs/bap_attack/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1431: UserWarning: Cannot retrieve user information assuming you are running in offline mode.
#   warnings.warn("Cannot retrieve user information assuming you are running in offline mode.")
# 100%|██████████| 10/10 [17:59<00:00, 107.91s/it]
# [Checkpoint] Saved to ckpts/catelmo_ensemble/step_0060
#
# Epoch 9:
# ['CASSLSYEQYF', 'CASSLSYEQYF', 'CASSLSYEQYF', 'CASSLAYEQYF', 'ASSSYEQ', 'CASSLSYEQYF', 'CASSLSYEQYF', 'CASSLNTEAFF', 'CASSLSYEQYF', 'CASSLSYEQYF', 'CASSYEQYF', 'CASSLSYEQYF', 'CASSYEQYF', 'CASSLSYEQYF', 'CASSLAYEQYF', 'ASSATEA', 'CASSQGYEQYF', 'CASSLSYEQYF', 'CASSLSYEQYF', 'CASSLSYEQYF']
